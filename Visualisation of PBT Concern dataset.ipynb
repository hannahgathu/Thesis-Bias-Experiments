# %%
import seaborn as sb
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('Training_dataset_PBT_Bendik_Commas.csv', sep=',')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-ca13525a867a> in <module>()
# ----> 1 df = pd.read_csv('Training_dataset_PBT_Bendik_Commas.csv', sep=',')
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     686     )
#     687
# ...

# %%
df = df.iloc[1:]

# %%
df = pd.read_csv('Training_dataset_PBT_Bendik_Commas_mark.csv', sep=',')

# %%
plt.show()

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', data=df)

# %%
g = sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', data=df)

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', data=df).set(xlim=(None, 1000))

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', data=df).set(xlim=(None, 2000))

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', data=df).set(xlim=(None, 1000)).set(ylim=(None,50000))

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', data=df).set(xlim=(None, 1000)).set(ylim=(0,10000))

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', data=df).set(xlim=(None, 250)).set(ylim=(0,2000))

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', data=df).set(xlim=(None, 50)).set(ylim=(0,250))

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', hue = 'STATUS_BIN', data=df).set(xlim=(None, 50)).set(ylim=(0,250))

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', hue = 'STATUS_BIN', data=df).set(xlim=(None, 1000)).set(ylim=(0,10000))

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', hue = 'STATUS_BIN', data=df)

# %%
sb.lmplot(x='t1/2 atmosphere in hours', y='BAF air', hue = 'STATUS_BIN', data=df).set(xlim=(None, 1500)).set(ylim=(0,20000))

# %% [markdown]
# **log kow vs Moleculair Weight**

# %%
sb.lmplot(x='log Kow (KowWin v1.67)', y='MW', hue = 'STATUS_BIN', data=df)

# %%
df.head()
# Out:
#         CAS-RN                     NAME STATUS_TEXT  STATUS_BIN  \
# 0  000050-00-0             Formaldehyde       not P           0
# 1  000056-81-5       1,2,3-Propanetriol       not P           0
# 2  000057-57-8              2-Oxetanone       not P           0
# 3  000060-12-8           Benzeneethanol       not P           0
# 4  000062-23-7   Benzoic acid, 4-nitro-       not P           0
#
#                       SMILES  k OH (AOPv1.92) atmospheric  \
# 0                        C=O                 8.130000e-12
# 1                   OCC(O)CO                 1.870000e-11
# 2                 O1C(=O)CC1                 6.140000e-13
# 3                OCCc1ccccc1                 1.020000e-11
# 4  N(=O)(=O)c1ccc(C(=O)O)cc1                 5.860000e-13
#
#    t1/2 atmosphere in hours  VP (mm Hg, MPVPBP v1.43)  VP (Pa, MPBPVPwin))  \
# 0                      47.4               3500.000000        465000.000000
# 1                      20.6                  0.000080             0.010600
# ...

# %%
sb.displot(df, x="log Kow (KowWin v1.67)")

# %%
sb.displot(df, x="log Kow (KowWin v1.67)", kind = "kde").set(xlim=(-10, 10))

# %%
sb.pairplot(df, vars=['log Kow (KowWin v1.67)','MW','BIOWIN3',])

# %%
sb.pairplot(df, vars=['log Kow (KowWin v1.67)','MW','BIOWIN3',], hue='STATUS_BIN',plot_kws={"s": 6})

# %%
g = sb.PairGrid(df, vars=['log Kow (KowWin v1.67)','MW','BIOWIN3',], hue='STATUS_BIN')
g.map_upper(plt.scatter)
g.map_lower(sb.kdeplot)
g.map_diag(sb.kdeplot)
plt.show()
